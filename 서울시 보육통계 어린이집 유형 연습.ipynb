# %% [markdown]
# <a href="https://colab.research.google.com/github/spacemaninSeoul/justpractice/blob/main/%EC%84%9C%EC%9A%B8%EC%8B%9C%20%EB%B3%B4%EC%9C%A1%ED%86%B5%EA%B3%84%20%EC%96%B4%EB%A6%B0%EC%9D%B4%EC%A7%91%20%EC%9C%A0%ED%98%95%20%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import chardet

with open('/content/서울특별시 보육통계 어린이집 유형별 영유아 현황(성별구분) 정보.csv', 'rb') as f:
     result = chardet.detect(f.read())
import pandas as pd



df = pd.read_csv(r'/content/서울특별시 보육통계 어린이집 유형별 영유아 현황(성별구분) 정보.csv', encoding =result['encoding'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   통계연도      49 non-null     int64
#  1   만나이       49 non-null     int64
#  2   만나이명칭     49 non-null     object
#  3   전체아동수_남   49 non-null     int64
#  4   국공립아동수_남  49 non-null     int64
#  5   민간아동수_남   49 non-null     int64
#  6   가정아동수_남   49 non-null     int64
#  7   기타아동수_남   49 non-null     int64
#  8   전체아동수_여   49 non-null     int64
#  9   국공립아동수_여  49 non-null     int64
#  10  민간아동수_여   49 non-null     int64
#  11  가정아동수_여   49 non-null     int64
#  12  기타아동수_여   49 non-null     int64
# dtypes: int64(12), object(1)
# memory usage: 5.1+ KB

# %%
df
# Out:
#     통계연도  만나이       만나이명칭  전체아동수_남  ...  국공립아동수_여  민간아동수_여  가정아동수_여  기타아동수_여
# 0   2020    0          0세     9878  ...      2736     1869     3758      261
# 1   2020    5          5세    12930  ...      6364     4595        6     1394
# 2   2020    4          4세    14778  ...      6950     5055       14     1826
# 3   2020    6  방과후 (6세이상)      832  ...       230      123        1      353
# 4   2020    3          3세    17274  ...      7780     6467       25     2148
# 5   2020    2          2세    24659  ...      9754     7329     4258     2221
# 6   2020    1          1세    21029  ...      7599     4970     5047     1747
# 7   2019    4          4세    14944  ...      6832     5517       11     1721
# 8   2019    6  방과후 (6세이상)     1019  ...       316      149        1      408
# 9   2019    5          5세    13491  ...      6413     4746       15     1427
# 10  2019    3          3세    19520  ...      8000     8155       24     2337
# ...

# %%
df.describe()
# Out:
#               통계연도        만나이  ...       가정아동수_여      기타아동수_여
# count    49.000000  49.000000  ...     49.000000    49.000000
# mean   2017.000000   3.000000  ...   2877.571429  1424.142857
# std       2.020726   2.020726  ...   3539.794574   713.964110
# min    2014.000000   0.000000  ...      1.000000   241.000000
# 25%    2015.000000   1.000000  ...     14.000000   758.000000
# 50%    2017.000000   3.000000  ...     51.000000  1636.000000
# 75%    2019.000000   5.000000  ...   6339.000000  2012.000000
# max    2020.000000   6.000000  ...  11023.000000  2446.000000
#
# [8 rows x 12 columns]

# %%
df_groupby = df.groupby(by='통계연도')
df_groupby.count()
# Out:
#       만나이  만나이명칭  전체아동수_남  국공립아동수_남  ...  국공립아동수_여  민간아동수_여  가정아동수_여  기타아동수_여
# 통계연도                                 ...
# 2014    7      7        7         7  ...         7        7        7        7
# 2015    7      7        7         7  ...         7        7        7        7
# 2016    7      7        7         7  ...         7        7        7        7
# 2017    7      7        7         7  ...         7        7        7        7
# 2018    7      7        7         7  ...         7        7        7        7
# 2019    7      7        7         7  ...         7        7        7        7
# 2020    7      7        7         7  ...         7        7        7        7
#
# [7 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
df_g = df.copy()
df_g.set_index('통계연도', inplace=True)
df_g
# Out:
#       만나이       만나이명칭  전체아동수_남  국공립아동수_남  ...  국공립아동수_여  민간아동수_여  가정아동수_여  기타아동수_여
# 통계연도                                      ...
# 2020    0          0세     9878      3190  ...      2736     1869     3758      261
# 2020    5          5세    12930      6683  ...      6364     4595        6     1394
# 2020    4          4세    14778      7400  ...      6950     5055       14     1826
# 2020    6  방과후 (6세이상)      832       331  ...       230      123        1      353
# 2020    3          3세    17274      8193  ...      7780     6467       25     2148
# 2020    2          2세    24659     10286  ...      9754     7329     4258     2221
# 2020    1          1세    21029      8429  ...      7599     4970     5047     1747
# 2019    4          4세    14944      7302  ...      6832     5517       11     1721
# 2019    6  방과후 (6세이상)     1019       424  ...       316      149        1      408
# 2019    5          5세    13491      6776  ...      6413     4746       15     1427
# ...

# %%
#통계연도 열을 기준으로 분할
grouped = df.groupby(['통계연도'])
print(grouped)

# %%
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)


for key, group in grouped:
  print("*key :", key)
  print(group)
  plt.plot('통계연도', )
  print()
# Out:
# pandas version:  1.1.5
# *key : 2014
#     통계연도  만나이       만나이명칭  전체아동수_남  국공립아동수_남  민간아동수_남  가정아동수_남  기타아동수_남  \
# 42  2014    1          1세    27792      4171    10626    11438     1557
# 43  2014    6  방과후 (6세이상)     1712       549      288        1      874
# 44  2014    5          5세    14328      5963     6905       21     1439
# 45  2014    4          4세    15576      6188     7678       33     1677
# 46  2014    3          3세    21969      6572    13010      176     2211
# 47  2014    2          2세    32779      6051    16188     8310     2230
# 48  2014    0          0세    11026       927     2662     7174      263
#
#     전체아동수_여  국공립아동수_여  민간아동수_여  가정아동수_여  기타아동수_여
# 42    26208      3876     9847    11023     1462
# 43     1671       534      259        3      875
# 44    13521      5537     6566       18     1400
# 45    14799      5909     7328       23     1539
# 46    20542      6120    12242      168     2012
# 47    31392      5820    15591     7919     2062
# ...
